# %% [markdown]
# # Module 8 Assignment
#
# Jahnavi Chintakindi
#
# ## Overview

# %% [markdown]
# Be sure to replace the stud_id variable with you student id. Automatic 0 if not properly replaced.

# %%
# create seed, run this cell as is, only edit your stud_id
import pandas as pd
import numpy as np
import pandas as pd
import string
import random
import re
from sklearn.datasets import make_regression

n = 500

def make_null(r, w):
    # rtn = random.choices([np.nan, r])
    wi = w * .1
    rtn = np.random.choice([r, np.NaN], p=[1-wi, wi])
    return re.sub(r"[\[\]]",'', str(rtn))


# provide your student id as stud_id, replace 123456789 (automatice 0 if not replaced with your student id)
stud_id = 123456789
my_seed = random.seed(11711379)

# Do not edit this cell beyond this line
variables = [''.join(random.choices(string.ascii_lowercase, k=4)) for _ in range(30)]
print(variables)

X, y = make_regression(n_samples=n, n_features=20, n_informative=12)
# random.shuffle(variables)
cols = variables[:20]
df = pd.DataFrame(data=X, columns=cols)
df[cols[0]] = round(df[cols[0]], 4)
df[variables[20]] = 0.03
df[variables[21]] = 0.07
df[variables[22]] = df[variables[0]]
df[variables[23]] = df[cols[1]]
df[variables[24]] = df[variables[20]].apply(make_null, args=(1,))
df[variables[25]] = df[variables[13]].apply(make_null, args=(1,))
df[variables[26]] = random.sample(range(100, 1000), k=n)
df[variables[27]] = random.sample(range(1000, 10000), k=n)
df[variables[28]] = np.random.choice([.4, .1], p=[.98, .02])

df[variables[7]] = df[variables[7]].apply(lambda r: abs(r) if (r < -0.03) else r)
df[variables[8]] = df[variables[8]].apply(lambda r: abs(r)*-1 if (r > 0.02) else r)
df[variables[9]] = df[variables[9]].apply(lambda r: abs(r) if (r < -0.01) else r)
df[variables[7]] = df[variables[7]].apply(make_null, args=(1,))
df[variables[8]] = df[variables[8]].apply(make_null, args=(1,))
df[variables[9]] = df[variables[9]].apply(make_null, args=(1,))
df[variables[17]] = df[variables[17]].apply(make_null, args=(1,))
df[variables[18]] = df[variables[18]].apply(make_null, args=(1,))
df[variables[19]] = df[variables[19]].apply(make_null, args=(1,))

df = df[np.random.default_rng(seed=my_seed).permutation(df.columns.values)]

df = df.assign(survival=[random.choice(['x', 'o']) for i in range(n)])
df = df.assign(treatment=[random.choice(['yes', 'no']) for i in range(n)])
df = df.assign(level=[random.choice(['level 1', 'level 2', 'level 3']) for i in range(n)])
df = df.assign(stage=[random.choice(['stage 5', 'stage 4', 'stage 3', 'stage 2', 'stage 1']) for i in range(n)])

df['target'] = y

dupes = df.loc[0:10]
df = pd.concat([df, dupes], axis=0)

df = df.sample(frac=1).reset_index(drop=True)

#df.to_csv('Assignment 8.csv', index=False) # comment this out after successful run so that you don't overwrite your data
# Out:
# ['azdo', 'ippn', 'kxtp', 'icwb', 'cdmq', 'wmej', 'rhud', 'jrjm', 'eigb', 'pixm', 'bhux', 'uzqa', 'qpnw', 'rugc', 'kafk', 'mfiv', 'lgsv', 'rirh', 'inxi', 'ozye', 'bnuu', 'bmzg', 'ibrj', 'ilat', 'dyly', 'tswu', 'zsvm', 'cgfh', 'nkjb', 'sfwq']

# %%
# read the dataset created above into a datagrame and output shape, info, and head
df =  pd.read_csv("Assignment 8.csv")
print("shape of the data frame is: ", df.shape)
print("Info of the Dataframe is: ",df.info())
df.head()
# Out:
# shape of the data frame is:  (511, 34)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511 entries, 0 to 510
# Data columns (total 34 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   eigb       447 non-null    float64
#  1   tswu       458 non-null    float64
#  2   cdmq       511 non-null    float64
#  3   uzqa       511 non-null    float64
#  4   wmej       511 non-null    float64
#  5   ilat       511 non-null    float64
#  6   bmzg       511 non-null    float64
#  7   azdo       511 non-null    float64
#  8   kafk       511 non-null    float64
#  9   icwb       511 non-null    float64
#  10  bhux       511 non-null    float64
#  11  qpnw       511 non-null    float64
#  12  ibrj       511 non-null    float64
#  13  kxtp       511 non-null    float64
#  14  rugc       511 non-null    float64
#  15  mfiv       511 non-null    float64
#  16  pixm       455 non-null    float64
#  17  dyly       452 non-null    float64
#  18  nkjb       511 non-null    float64
#  19  zsvm       511 non-null    int64
#  20  inxi       462 non-null    float64
#  21  ippn       511 non-null    float64
#  22  lgsv       511 non-null    float64
#  23  rirh       451 non-null    float64
#  24  bnuu       511 non-null    float64
#  25  cgfh       511 non-null    int64
#  26  rhud       511 non-null    float64
#  27  jrjm       451 non-null    float64
#  28  ozye       469 non-null    float64
#  29  survival   511 non-null    object
#  30  treatment  511 non-null    object
#  31  level      511 non-null    object
#  32  stage      511 non-null    object
#  33  target     511 non-null    float64
# dtypes: float64(28), int64(2), object(4)
# memory usage: 135.9+ KB
# Info of the Dataframe is:  None
#        eigb      tswu      cdmq      uzqa      wmej      ilat  bmzg    azdo  \
# 0 -0.886577  0.970231 -0.297125  0.557473  0.391872  0.038483  0.07  1.1915
# 1 -1.889511 -2.369415  1.058176  2.687109 -1.458493 -1.059355  0.07  0.4427
# 2 -1.314165 -0.974687  0.133256 -1.193783  0.499094 -0.566857  0.07 -0.0923
# 3 -0.879092  0.095040  0.476540 -0.423896  0.687344  1.203585  0.07 -1.9210
# 4 -2.262015  0.456073  0.442172  0.844493  1.950927 -0.740844  0.07  1.0009
#
#        kafk      icwb  ...  bnuu  cgfh      rhud      jrjm      ozye  \
# 0 -0.019602 -1.321315  ...  0.03  1822  0.996646  0.356477       NaN
# 1  0.876609 -0.750648  ...  0.03  3968 -0.083492  1.723936 -0.046310
# 2 -0.094558  0.886522  ...  0.03  9937  0.446484  0.130250 -0.398677
# 3  0.856856 -1.461843  ...  0.03  4442 -0.278884  0.367868  0.570414
# 4  0.993574  0.187374  ...  0.03  2541  1.472499  0.657675 -0.855399
#
#    survival  treatment    level    stage      target
# 0         o        yes  level 2  stage 4  113.798757
# 1         x         no  level 2  stage 5 -383.810284
# 2         x         no  level 3  stage 2  -80.182770
# 3         o        yes  level 1  stage 4 -217.971707
# 4         x         no  level 1  stage 1 -200.026584
#
# [5 rows x 34 columns]

# %%
df.isna().sum()
# Out:
# eigb         64
# tswu         53
# cdmq          0
# uzqa          0
# wmej          0
# ilat          0
# bmzg          0
# azdo          0
# kafk          0
# icwb          0
# bhux          0
# qpnw          0
# ibrj          0
# kxtp          0
# rugc          0
# mfiv          0
# pixm         56
# dyly         59
# nkjb          0
# zsvm          0
# inxi         49
# ippn          0
# lgsv          0
# rirh         60
# bnuu          0
# cgfh          0
# rhud          0
# jrjm         60
# ozye         42
# survival      0
# treatment     0
# level         0
# stage         0
# target        0
# dtype: int64

# %%
# output and drop constants
constants = [ x for x in df.columns if len(df[x].fillna(0).unique()) == 1 ]

constants
# Out:
# ['bmzg', 'nkjb', 'bnuu']

# %%
df.drop(constants, axis=1, inplace=True)
df.shape
# Out:
# (511, 31)

# %%
# output quasi constants and drop quasi constants (don't drop bi-label features)
df['rirh']
# Out:
# 0     -0.233280
# 1     -0.981702
# 2     -0.431793
# 3     -1.606391
# 4     -0.196956
#          ...
# 506    0.182453
# 507    0.008018
# 508    1.329000
# 509    1.296610
# 510   -0.561838
# Name: rirh, Length: 511, dtype: float64

# %%
quasi_constants = []
for val in df.columns.sort_values():
    if (len(df[val].unique()) < 3):
        val_counts = df[val].value_counts(normalize=True)
        print(val_counts)
        if list(val_counts)[0] > 0.98:
            quasi_constants.append(val)

print('quasi_constants: ', quasi_constants)
# Out:
# 0.03    1.0
# Name: dyly, dtype: float64
# o    0.55773
# x    0.44227
# Name: survival, dtype: float64
# yes    0.530333
# no     0.469667
# Name: treatment, dtype: float64
# quasi_constants:  ['dyly']

# %%
print("shape of the df before the dropping Quasi Constant columns:", df.shape)
df.drop(quasi_constants,axis = 1,inplace =True)
print("shape of the df after the dropping Quasi Constant columns:", df.shape)
df.info()
# Out:
# shape of the df before the dropping Quasi Constant columns: (511, 31)
# shape of the df after the dropping Quasi Constant columns: (511, 30)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511 entries, 0 to 510
# Data columns (total 30 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   eigb       447 non-null    float64
#  1   tswu       458 non-null    float64
#  2   cdmq       511 non-null    float64
#  3   uzqa       511 non-null    float64
#  4   wmej       511 non-null    float64
#  5   ilat       511 non-null    float64
#  6   azdo       511 non-null    float64
#  7   kafk       511 non-null    float64
#  8   icwb       511 non-null    float64
#  9   bhux       511 non-null    float64
#  10  qpnw       511 non-null    float64
#  11  ibrj       511 non-null    float64
#  12  kxtp       511 non-null    float64
#  13  rugc       511 non-null    float64
#  14  mfiv       511 non-null    float64
#  15  pixm       455 non-null    float64
#  16  zsvm       511 non-null    int64
#  17  inxi       462 non-null    float64
#  18  ippn       511 non-null    float64
#  19  lgsv       511 non-null    float64
#  20  rirh       451 non-null    float64
#  21  cgfh       511 non-null    int64
#  22  rhud       511 non-null    float64
#  23  jrjm       451 non-null    float64
#  24  ozye       469 non-null    float64
#  25  survival   511 non-null    object
#  26  treatment  511 non-null    object
#  27  level      511 non-null    object
#  28  stage      511 non-null    object
#  29  target     511 non-null    float64
# dtypes: float64(24), int64(2), object(4)
# memory usage: 119.9+ KB

# %%
# output and drop duplicate rows, print shape
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 506     True
# 507    False
# 508    False
# 509    False
# 510     True
# Length: 511, dtype: bool

# %%
# check of duplicate columns
print("shape before: ",df.shape)
df.drop_duplicates(inplace = True)
print("shape after: ",df.shape)
# Out:
# shape before:  (511, 30)
# shape after:  (500, 30)

# %%
# drop duplicate features and output shape
duplicate_columns = []
for i in range(0, len(df.columns)):
    original = df.columns[i]

    for duplicate in df.columns[i + 1:]:
        if df[original].equals(df[duplicate]):
            duplicate_columns.append(duplicate)
            print(f'{original} looks the same as {duplicate}')

duplicate_columns
# Out:
# ilat looks the same as ippn
# azdo looks the same as ibrj
# ['ippn', 'ibrj']

# %%
print("shape before: ",df.shape)
df.drop(duplicate_columns, axis=1, inplace = True)
print("shape after: ",df.shape)
df.info()
# Out:
# shape before:  (500, 30)
# shape after:  (500, 28)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 509
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   eigb       437 non-null    float64
#  1   tswu       448 non-null    float64
#  2   cdmq       500 non-null    float64
#  3   uzqa       500 non-null    float64
#  4   wmej       500 non-null    float64
#  5   ilat       500 non-null    float64
#  6   azdo       500 non-null    float64
#  7   kafk       500 non-null    float64
#  8   icwb       500 non-null    float64
#  9   bhux       500 non-null    float64
#  10  qpnw       500 non-null    float64
#  11  kxtp       500 non-null    float64
#  12  rugc       500 non-null    float64
#  13  mfiv       500 non-null    float64
#  14  pixm       445 non-null    float64
#  15  zsvm       500 non-null    int64
#  16  inxi       451 non-null    float64
#  17  lgsv       500 non-null    float64
#  18  rirh       440 non-null    float64
#  19  cgfh       500 non-null    int64
#  20  rhud       500 non-null    float64
#  21  jrjm       441 non-null    float64
#  22  ozye       460 non-null    float64
#  23  survival   500 non-null    object
#  24  treatment  500 non-null    object
#  25  level      500 non-null    object
#  26  stage      500 non-null    object
#  27  target     500 non-null    float64
# dtypes: float64(22), int64(2), object(4)
# memory usage: 113.3+ KB

# %% [markdown]
# ### Imputation
#
# Use histograms to view the shape of your numerical features.
# * Use median to replace missing data for skewed features
# * Use interpolation to replace missing data for features that look normal

# %%
# plot histograms
import matplotlib.pyplot as plt

df.hist()
plt.tight_layout();

# %%
# show null values for each variable
df.isnull().sum()
# Out:
# eigb         63
# tswu         52
# cdmq          0
# uzqa          0
# wmej          0
# ilat          0
# azdo          0
# kafk          0
# icwb          0
# bhux          0
# qpnw          0
# kxtp          0
# rugc          0
# mfiv          0
# pixm         55
# zsvm          0
# inxi         49
# lgsv          0
# rirh         60
# cgfh          0
# rhud          0
# jrjm         59
# ozye         40
# survival      0
# treatment     0
# level         0
# stage         0
# target        0
# dtype: int64

# %%
# print info to recall which variables are numeric vs categorical
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 509
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   eigb       437 non-null    float64
#  1   tswu       448 non-null    float64
#  2   cdmq       500 non-null    float64
#  3   uzqa       500 non-null    float64
#  4   wmej       500 non-null    float64
#  5   ilat       500 non-null    float64
#  6   azdo       500 non-null    float64
#  7   kafk       500 non-null    float64
#  8   icwb       500 non-null    float64
#  9   bhux       500 non-null    float64
#  10  qpnw       500 non-null    float64
#  11  kxtp       500 non-null    float64
#  12  rugc       500 non-null    float64
#  13  mfiv       500 non-null    float64
#  14  pixm       445 non-null    float64
#  15  zsvm       500 non-null    int64
#  16  inxi       451 non-null    float64
#  17  lgsv       500 non-null    float64
#  18  rirh       440 non-null    float64
#  19  cgfh       500 non-null    int64
#  20  rhud       500 non-null    float64
#  21  jrjm       441 non-null    float64
#  22  ozye       460 non-null    float64
#  23  survival   500 non-null    object
#  24  treatment  500 non-null    object
#  25  level      500 non-null    object
#  26  stage      500 non-null    object
#  27  target     500 non-null    float64
# dtypes: float64(22), int64(2), object(4)
# memory usage: 113.3+ KB

# %%
# replace missing data with appropriate mean, median, or mode and confirm with isnull().sum()
numeric_columns = df.select_dtypes(include=['number']).columns
categorical_columns = df.select_dtypes(include=['object']).columns

for column in numeric_columns:
    if df[column].skew() > 1.0:
        median = df[column].median()
        df[column].fillna(median, inplace=True)
    else:
        mean = df[column].mean()
        df[column].fillna(mean, inplace=True)

for column in categorical_columns:
    mode = df[column].mode()[0]
    df[column].fillna(mode, inplace=True)
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# eigb         0
# tswu         0
# cdmq         0
# uzqa         0
# wmej         0
# ilat         0
# azdo         0
# kafk         0
# icwb         0
# bhux         0
# qpnw         0
# kxtp         0
# rugc         0
# mfiv         0
# pixm         0
# zsvm         0
# inxi         0
# lgsv         0
# rirh         0
# cgfh         0
# rhud         0
# jrjm         0
# ozye         0
# survival     0
# treatment    0
# level        0
# stage        0
# target       0
# dtype: int64

# %% [markdown]
# ### Train Test Split

# %%
# train test split (target is the dependent (y) variable), print the shapes for X_train and X_test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df.drop('target', axis=1),
    df['target'],
    test_size=0.25,
    random_state=42)

# %% [markdown]
# **Important:** We will not be using df (the dataframe we created above) for the remaining code. Instead we will be using X_train for df and X_test when appropriate.

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# describe X_train
X_train.describe()
# Out:
#              eigb        tswu        cdmq        uzqa        wmej        ilat  \
# count  375.000000  375.000000  375.000000  375.000000  375.000000  375.000000
# mean    -0.799693    0.046952    0.007492    0.094250    0.033595    0.070325
# std      0.559042    0.957103    1.049254    0.974136    1.005539    0.990099
# min     -2.766730   -3.056520   -3.378864   -3.126829   -3.016525   -3.869796
# 25%     -1.024349   -0.466613   -0.678204   -0.587349   -0.635803   -0.540935
# 50%     -0.817626    0.025098    0.056180    0.118559    0.033764    0.104425
# 75%     -0.361511    0.607369    0.672938    0.712884    0.750610    0.690573
# max      0.012502    2.802554    3.349607    2.687109    2.851641    2.933280
#
#              azdo        kafk        icwb        bhux  ...        mfiv  \
# count  375.000000  375.000000  375.000000  375.000000  ...  375.000000
# mean    -0.007007    0.052883   -0.011282   -0.028114  ...    0.064389
# std      0.957026    1.064609    0.966839    1.027177  ...    1.010678
# min     -3.080900   -2.815087   -2.719260   -2.646445  ...   -2.996978
# 25%     -0.624700   -0.656084   -0.695361   -0.739885  ...   -0.568389
# 50%     -0.005900    0.018685   -0.005614    0.065972  ...    0.136820
# 75%      0.628500    0.736506    0.683266    0.660864  ...    0.707506
# max      3.875400    2.980591    3.116902    2.654338  ...    2.813596
#
#              pixm        zsvm        inxi        lgsv        rirh        cgfh  \
# count  375.000000  375.000000  375.000000  375.000000  375.000000  375.000000
# mean     0.769466    0.004390   -0.005394   -0.123082    0.046676   -0.050891
# std      0.588190    1.003854    0.915053    0.963942    0.927677    0.966780
# min     -0.003836   -1.737032   -2.563566   -2.851385   -2.556004   -1.731253
# 25%      0.376225   -0.853119   -0.538162   -0.800157   -0.537645   -0.913009
# 50%      0.645235    0.026874   -0.017343   -0.129057    0.031918   -0.086584
# 75%      1.063629    0.899028    0.546574    0.546014    0.642901    0.729713
# max      3.395348    1.751582    2.614076    2.158618    2.995581    1.762987
#
#              rhud        jrjm        ozye
# count  375.000000  375.000000  375.000000
# mean     0.019722    0.850591   -0.060484
# std      0.957556    0.604312    1.005610
# min     -2.720536    0.007698   -3.429500
# 25%     -0.620871    0.409376   -0.689996
# 50%      0.004584    0.806787   -0.031292
# 75%      0.690962    1.138451    0.544662
# max      2.908501    3.134322    2.773427
#
# [8 rows x 23 columns]

# %% [markdown]
# Using X_train.describe(), identify the two features with max values greater than 100. These features have scales that are quite different than the other features and must be scaled so that they share the same scale as the other features. Standardize one feature and Normalize the other feature.

# %%
from sklearn.preprocessing import StandardScaler

feat = X_train._get_numeric_data().idxmax(1).iloc[0]
scaler = StandardScaler()
X_train[feat] = scaler.fit_transform(X_train[[feat]].values)
X_test[feat] = scaler.transform(X_test[[feat]].values)

# %%
# normalize feature
from sklearn.preprocessing import MinMaxScaler

feat = X_train._get_numeric_data().idxmax(1).iloc[0]
scaler = MinMaxScaler()
X_train[feat] = scaler.fit_transform(X_train[[feat]].values)
X_test[feat] = scaler.transform(X_test[[feat]].values)

# %%
# describe X_train again to verify transformations
X_train.describe()
# Out:
#              eigb        tswu        cdmq        uzqa        wmej        ilat  \
# count  375.000000  375.000000  375.000000  375.000000  375.000000  375.000000
# mean    -0.799693    0.046952    0.007492    0.094250    0.033595    0.070325
# std      0.559042    0.957103    1.049254    0.974136    1.005539    0.990099
# min     -2.766730   -3.056520   -3.378864   -3.126829   -3.016525   -3.869796
# 25%     -1.024349   -0.466613   -0.678204   -0.587349   -0.635803   -0.540935
# 50%     -0.817626    0.025098    0.056180    0.118559    0.033764    0.104425
# 75%     -0.361511    0.607369    0.672938    0.712884    0.750610    0.690573
# max      0.012502    2.802554    3.349607    2.687109    2.851641    2.933280
#
#              azdo        kafk        icwb        bhux  ...        mfiv  \
# count  375.000000  375.000000  375.000000  375.000000  ...  375.000000
# mean    -0.007007    0.052883   -0.011282   -0.028114  ...    0.064389
# std      0.957026    1.064609    0.966839    1.027177  ...    1.010678
# min     -3.080900   -2.815087   -2.719260   -2.646445  ...   -2.996978
# 25%     -0.624700   -0.656084   -0.695361   -0.739885  ...   -0.568389
# 50%     -0.005900    0.018685   -0.005614    0.065972  ...    0.136820
# 75%      0.628500    0.736506    0.683266    0.660864  ...    0.707506
# max      3.875400    2.980591    3.116902    2.654338  ...    2.813596
#
#              pixm        zsvm        inxi        lgsv        rirh        cgfh  \
# count  375.000000  375.000000  375.000000  375.000000  375.000000  375.000000
# mean     0.769466    0.004390   -0.005394   -0.123082    0.046676   -0.050891
# std      0.588190    1.003854    0.915053    0.963942    0.927677    0.966780
# min     -0.003836   -1.737032   -2.563566   -2.851385   -2.556004   -1.731253
# 25%      0.376225   -0.853119   -0.538162   -0.800157   -0.537645   -0.913009
# 50%      0.645235    0.026874   -0.017343   -0.129057    0.031918   -0.086584
# 75%      1.063629    0.899028    0.546574    0.546014    0.642901    0.729713
# max      3.395348    1.751582    2.614076    2.158618    2.995581    1.762987
#
#              rhud        jrjm        ozye
# count  375.000000  375.000000  375.000000
# mean     0.486808    0.850591   -0.060484
# std      0.170110    0.604312    1.005610
# min      0.000000    0.007698   -3.429500
# 25%      0.373006    0.409376   -0.689996
# 50%      0.484118    0.806787   -0.031292
# 75%      0.606054    1.138451    0.544662
# max      1.000000    3.134322    2.773427
#
# [8 rows x 23 columns]

# %%
# X_train.info()
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375 entries, 229 to 102
# Data columns (total 27 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   eigb       375 non-null    float64
#  1   tswu       375 non-null    float64
#  2   cdmq       375 non-null    float64
#  3   uzqa       375 non-null    float64
#  4   wmej       375 non-null    float64
#  5   ilat       375 non-null    float64
#  6   azdo       375 non-null    float64
#  7   kafk       375 non-null    float64
#  8   icwb       375 non-null    float64
#  9   bhux       375 non-null    float64
#  10  qpnw       375 non-null    float64
#  11  kxtp       375 non-null    float64
#  12  rugc       375 non-null    float64
#  13  mfiv       375 non-null    float64
#  14  pixm       375 non-null    float64
#  15  zsvm       375 non-null    float64
#  16  inxi       375 non-null    float64
#  17  lgsv       375 non-null    float64
#  18  rirh       375 non-null    float64
#  19  cgfh       375 non-null    float64
#  20  rhud       375 non-null    float64
#  21  jrjm       375 non-null    float64
#  22  ozye       375 non-null    float64
#  23  survival   375 non-null    object
#  24  treatment  375 non-null    object
#  25  level      375 non-null    object
#  26  stage      375 non-null    object
# dtypes: float64(23), object(4)
# memory usage: 82.0+ KB

# %%
# check for outliers
for feat in X_train._get_numeric_data().columns[1:]:
    q1 = X_train[feat].quantile(0.25)
    q3 = X_train[feat].quantile(0.75)
    iqr = q3 - q1
    lower_fence = (q1 - 1.5 * iqr).round()
    upper_fence = (q3 + 1.5 * iqr).round()
    lower_count = X_train[feat][X_train[feat] < lower_fence].count()
    upper_count = X_train[feat][X_train[feat] > upper_fence].count()
    print(f'{feat} outliers = {lower_count + upper_count}: lower_fence: {lower_fence}, upper_fence: {upper_fence}, lower_count: {lower_count}, upper_count: {upper_count}')
# Out:
# tswu outliers = 17: lower_fence: -2.0, upper_fence: 2.0, lower_count: 9, upper_count: 8
# cdmq outliers = 2: lower_fence: -3.0, upper_fence: 3.0, lower_count: 1, upper_count: 1
# uzqa outliers = 1: lower_fence: -3.0, upper_fence: 3.0, lower_count: 1, upper_count: 0
# wmej outliers = 1: lower_fence: -3.0, upper_fence: 3.0, lower_count: 1, upper_count: 0
# ilat outliers = 9: lower_fence: -2.0, upper_fence: 3.0, lower_count: 9, upper_count: 0
# azdo outliers = 2: lower_fence: -3.0, upper_fence: 3.0, lower_count: 1, upper_count: 1
# kafk outliers = 0: lower_fence: -3.0, upper_fence: 3.0, lower_count: 0, upper_count: 0
# icwb outliers = 1: lower_fence: -3.0, upper_fence: 3.0, lower_count: 0, upper_count: 1
# bhux outliers = 0: lower_fence: -3.0, upper_fence: 3.0, lower_count: 0, upper_count: 0
# qpnw outliers = 1: lower_fence: -3.0, upper_fence: 3.0, lower_count: 1, upper_count: 0
# kxtp outliers = 3: lower_fence: -3.0, upper_fence: 3.0, lower_count: 2, upper_count: 1
# rugc outliers = 9: lower_fence: -2.0, upper_fence: 3.0, lower_count: 9, upper_count: 0
# mfiv outliers = 10: lower_fence: -2.0, upper_fence: 3.0, lower_count: 10, upper_count: 0
# pixm outliers = 18: lower_fence: -1.0, upper_fence: 2.0, lower_count: 0, upper_count: 18
# zsvm outliers = 0: lower_fence: -3.0, upper_fence: 4.0, lower_count: 0, upper_count: 0
# inxi outliers = 8: lower_fence: -2.0, upper_fence: 2.0, lower_count: 3, upper_count: 5
# lgsv outliers = 0: lower_fence: -3.0, upper_fence: 3.0, lower_count: 0, upper_count: 0
# rirh outliers = 15: lower_fence: -2.0, upper_fence: 2.0, lower_count: 7, upper_count: 8
# cgfh outliers = 0: lower_fence: -3.0, upper_fence: 3.0, lower_count: 0, upper_count: 0
# rhud outliers = 0: lower_fence: 0.0, upper_fence: 1.0, lower_count: 0, upper_count: 0
# jrjm outliers = 22: lower_fence: -1.0, upper_fence: 2.0, lower_count: 0, upper_count: 22
# ozye outliers = 10: lower_fence: -3.0, upper_fence: 2.0, lower_count: 3, upper_count: 7

# %%
# show correlation heat map for features, check for multicollinearity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# correlation matrix
sns.set(style="white")

# compute the correlation matrix
corr = X_train._get_numeric_data().corr()

# generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# set up the matplotlib figure
# f, ax = plt.subplots()
f = plt.figure(figsize=(10, 10))

# generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True);

plt.tight_layout()

# %%
# https://gist.github.com/wjptak/88575bbc5dde446e1186ffd41475c0f1
# identify pairs of correlated features

hi_corr = []

def get_highly_correlated_pairs(df, features, threshold=0.5):
  corr_df = df[features].corr() # get correlations
  correlated_features = np.where(np.abs(corr_df) > threshold) # select ones above the abs threshold
  correlated_features = [(corr_df.iloc[x,y], x, y) for x, y in zip(*correlated_features) if x != y and x < y] # avoid duplication
  s_corr_list = sorted(correlated_features, key=lambda x: -abs(x[0])) # sort by correlation value

  if s_corr_list == []:
    print("There are no highly correlated features with correlation above", threshold)
  else:
    for v, i, j in s_corr_list:
      cols = df[features].columns
      # print ("%s and %s = %.3f" % (corr_df.index[i], corr_df.columns[j], v))
      hi_corr.append([corr_df.index[i], corr_df.index[j]])

get_highly_correlated_pairs(X_train._get_numeric_data(), X_train._get_numeric_data().columns)
# hi_corr
# Out:
# There are no highly correlated features with correlation above 0.5

# %%
# delete one of the features out of the pair(s) that show multicollinearity
for pairs in hi_corr:
  # print(pairs[0])
  X_train.drop(pairs[0], axis=1, inplace=True)
  X_test.drop(pairs[0], axis=1, inplace=True)

# %%
# vif test
from statsmodels.stats.outliers_influence import variance_inflation_factor

X = X_train._get_numeric_data().dropna().copy()
# add constant
X.insert(0, 'const', 1)

# create dataframe to store vif information
vif = pd.DataFrame()
vif['Feature'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# remove constant (first row) and show vif dataframe
X.drop('const', axis=1, inplace=True)
vif = vif.iloc[1: , :]
vif
# Out:
#    Feature       VIF
# 1     eigb  1.065531
# 2     cdmq  1.031376
# 3     uzqa  1.049006
# 4     wmej  1.067197
# 5     ilat  1.050228
# 6     azdo  1.059983
# 7     kafk  1.077179
# 8     icwb  1.097145
# 9     bhux  1.062293
# 10    qpnw  1.074975
# 11    kxtp  1.051622
# 12    rugc  1.059318
# 13    mfiv  1.045082
# 14    pixm  1.035667
# 15    zsvm  1.070703
# 16    inxi  1.081287
# 17    lgsv  1.056774
# 18    rirh  1.092908
# 19    cgfh  1.033077
# 20    rhud  1.065551
# 21    jrjm  1.067757
# 22    ozye  1.058380

# %%
# show correlation heat map for features, check for multicollinearity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# correlation matrix
sns.set(style="white")

# compute the correlation matrix
corr = X_train._get_numeric_data().corr()

# generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# set up the matplotlib figure
# f, ax = plt.subplots()
f = plt.figure(figsize=(10, 10))

# generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True);

plt.tight_layout()

# %%
# correlation with target
X_train._get_numeric_data().corrwith(y_train).plot.bar(
        title = 'Correlation with Dependent Variable', rot = 90, grid = True);

# %% [markdown]
# ### Create the Models

# %%
# sklearn linear regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

lr_model = LinearRegression()
lr_model.fit(X_train._get_numeric_data(), y_train)
# lr_feat_coeffs = list(zip(X_train._get_numeric_data(), lr_model.coef_))
feats = ['const']
feats.extend(X_train._get_numeric_data().columns)
coefs = [lr_model.intercept_]
coefs.extend(lr_model.coef_)
d = {'Feature': feats, 'Coef': coefs}
lr_df = pd.DataFrame(d)
print(lr_df)

# test set prediction results
yhat = lr_model.predict(X_test._get_numeric_data())
print(f'MSE: {mean_squared_error(y_true=y_test, y_pred=yhat)}')
print(f'R-Squared: {r2_score(y_test, yhat)}')
# Out:
#    Feature        Coef
# 0    const -107.384204
# 1     eigb   -8.960930
# 2     cdmq    0.076619
# 3     uzqa   -2.765886
# 4     wmej    1.294516
# 5     ilat   70.980843
# 6     azdo   42.506779
# 7     kafk   -7.255580
# 8     icwb   82.854626
# 9     bhux    0.635165
# 10    qpnw   81.288660
# 11    kxtp   -0.103660
# 12    rugc   51.351805
# 13    mfiv    4.665903
# 14    pixm  -16.158217
# 15    zsvm   -1.939995
# 16    inxi   83.310797
# 17    lgsv    1.295766
# 18    rirh    0.861688
# 19    cgfh    0.858174
# 20    rhud  214.060280
# 21    jrjm    4.724680
# 22    ozye   27.674017
# MSE: 6148.410141080466
# R-Squared: 0.8481738217228745

# %%
# statsmodel ols with summary
import statsmodels.api as sm

# features should have a constant or intercept
# X_train = sm.add_constant(X_train)
X_with_const = X_train._get_numeric_data().copy()
X_with_const.insert(0, 'const', 1)
ols_model = sm.OLS(y_train, X_with_const).fit()
print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     101.3
# Date:                Thu, 19 Oct 2023   Prob (F-statistic):          1.25e-137
# Time:                        04:16:23   Log-Likelihood:                -2121.0
# No. Observations:                 375   AIC:                             4288.
# Df Residuals:                     352   BIC:                             4378.
# Df Model:                          22
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -107.3842     15.044     -7.138      0.000    -136.972     -77.797
# eigb          -8.9609      6.820     -1.314      0.190     -22.373       4.452
# cdmq           0.0766      3.575      0.021      0.983      -6.954       7.107
# uzqa          -2.7659      3.883     -0.712      0.477     -10.403       4.871
# wmej           1.2945      3.794      0.341      0.733      -6.168       8.757
# ilat          70.9808      3.823     18.567      0.000      63.462      78.499
# azdo          42.5068      3.973     10.698      0.000      34.692      50.321
# kafk          -7.2556      3.601     -2.015      0.045     -14.337      -0.174
# icwb          82.8546      4.001     20.707      0.000      74.985      90.724
# bhux           0.6352      3.706      0.171      0.864      -6.654       7.924
# qpnw          81.2887      3.715     21.882      0.000      73.983      88.595
# kxtp          -0.1037      3.694     -0.028      0.978      -7.369       7.162
# rugc          51.3518      3.795     13.533      0.000      43.889      58.815
# mfiv           4.6659      3.736      1.249      0.213      -2.682      12.013
# pixm         -16.1582      6.390     -2.529      0.012     -28.726      -3.590
# zsvm          -1.9400      3.807     -0.510      0.611      -9.427       5.548
# inxi          83.3108      4.197     19.849      0.000      75.056      91.565
# lgsv           1.2958      3.939      0.329      0.742      -6.451       9.042
# rirh           0.8617      4.162      0.207      0.836      -7.324       9.048
# cgfh           0.8582      3.883      0.221      0.825      -6.779       8.495
# rhud         214.0603     22.412      9.551      0.000     169.981     258.139
# jrjm           4.7247      6.315      0.748      0.455      -7.696      17.145
# ozye          27.6740      3.779      7.324      0.000      20.243      35.105
# ==============================================================================
# Omnibus:                       12.971   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               19.484
# Skew:                           0.255   Prob(JB):                     5.88e-05
# Kurtosis:                       3.993   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# show the coefficient using linear algebra matrices
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# linalg needs constant that was inserted for OLS and we already have OLS model
print('Sklearn Linear Regression Model')
print(lr_df)
# print(lr_model.intercept_)
print()
print('StatsModel')
print(ols_model.params)
print()

X = X_with_const
y = y_train
print('Numpy Linear Algebra')
print('weights = ', np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y))
# Out:
# Sklearn Linear Regression Model
#    Feature        Coef
# 0    const -107.384204
# 1     eigb   -8.960930
# 2     cdmq    0.076619
# 3     uzqa   -2.765886
# 4     wmej    1.294516
# 5     ilat   70.980843
# 6     azdo   42.506779
# 7     kafk   -7.255580
# 8     icwb   82.854626
# 9     bhux    0.635165
# 10    qpnw   81.288660
# 11    kxtp   -0.103660
# 12    rugc   51.351805
# 13    mfiv    4.665903
# 14    pixm  -16.158217
# 15    zsvm   -1.939995
# 16    inxi   83.310797
# 17    lgsv    1.295766
# 18    rirh    0.861688
# 19    cgfh    0.858174
# 20    rhud  214.060280
# 21    jrjm    4.724680
# 22    ozye   27.674017
#
# StatsModel
# const   -107.384204
# eigb      -8.960930
# cdmq       0.076619
# uzqa      -2.765886
# wmej       1.294516
# ilat      70.980843
# azdo      42.506779
# kafk      -7.255580
# icwb      82.854626
# bhux       0.635165
# qpnw      81.288660
# kxtp      -0.103660
# rugc      51.351805
# mfiv       4.665903
# pixm     -16.158217
# zsvm      -1.939995
# inxi      83.310797
# lgsv       1.295766
# rirh       0.861688
# cgfh       0.858174
# rhud     214.060280
# jrjm       4.724680
# ozye      27.674017
# dtype: float64
#
# Numpy Linear Algebra
# weights =  [-1.07384204e+02 -8.96092968e+00  7.66187439e-02 -2.76588613e+00
#   1.29451560e+00  7.09808435e+01  4.25067793e+01 -7.25557967e+00
#   8.28546257e+01  6.35165203e-01  8.12886600e+01 -1.03659745e-01
#   5.13518047e+01  4.66590258e+00 -1.61582165e+01 -1.93999469e+00
#   8.33107968e+01  1.29576575e+00  8.61687780e-01  8.58173861e-01
#   2.14060280e+02  4.72467979e+00  2.76740166e+01]

# %% [markdown]
# #### Lasso / l1 Regularization
#
# * $\alpha = \sum|w_i|$
# * Forces weak features to have zero coefficients
# * Performs feature selection
# * Models can be unstable (coefficients fluctuate significantly on data changes with correlated features)

# %%
# create X _get_numeric_data() without constant

X_reg=X_with_const.drop('const',axis=1).copy()
print(X_reg.columns)
X_reg_test=X_test[X_reg.columns]
print(X_reg_test.columns)
# Out:
# Index(['eigb', 'cdmq', 'uzqa', 'wmej', 'ilat', 'azdo', 'kafk', 'icwb', 'bhux',
#        'qpnw', 'kxtp', 'rugc', 'mfiv', 'pixm', 'zsvm', 'inxi', 'lgsv', 'rirh',
#        'cgfh', 'rhud', 'jrjm', 'ozye'],
#       dtype='object')
# Index(['eigb', 'cdmq', 'uzqa', 'wmej', 'ilat', 'azdo', 'kafk', 'icwb', 'bhux',
#        'qpnw', 'kxtp', 'rugc', 'mfiv', 'pixm', 'zsvm', 'inxi', 'lgsv', 'rirh',
#        'cgfh', 'rhud', 'jrjm', 'ozye'],
#       dtype='object')

# %%
# lasso regularization
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
X=scaler.fit_transform(X_reg)
y=y_train
lasso_feats=X_reg.columns
lasso=Lasso(alpha=5)
lasso.fit(X,y)

d={'Feature' : lasso_feats, 'Coef' : lasso.coef_}
lasso_df=pd.DataFrame(d)
print(lasso_df)
# Out:
#    Feature       Coef
# 0     eigb  -0.000000
# 1     cdmq  -0.000000
# 2     uzqa  -0.000000
# 3     wmej   0.000000
# 4     ilat  64.922674
# 5     azdo  35.979376
# 6     kafk  -2.763783
# 7     icwb  75.003580
# 8     bhux  -0.000000
# 9     qpnw  77.770297
# 10    kxtp  -0.000000
# 11    rugc  46.933818
# 12    mfiv   0.000000
# 13    pixm  -4.416576
# 14    zsvm  -0.000000
# 15    inxi  71.669928
# 16    lgsv   0.000000
# 17    rirh   0.000000
# 18    cgfh  -0.000000
# 19    rhud  31.773544
# 20    jrjm   0.000000
# 21    ozye  21.928699

# %% [markdown]
# #### Ridge / l2 Regularization
#
# * $\alpha = \sum w_i^2$
# * Spreads out coefficients more equally
# * Exposes correlated features (have similar coefficients)
# * Models are more stable (coefficients don't fluctuate as much on data changes with correlated features)

# %%
# ridge regularization

from sklearn.linear_model import Ridge

scaler = StandardScaler()

# .values is used to avoid warning about training on feature names
# UserWarning: X has feature names, but Ridge was fitted without feature names
X = scaler.fit_transform(X_reg.values)
X_reg_test = scaler.transform(X_reg_test.values)
y = y_train.values
y_reg_test = y_test.values

ridge_feats = X_reg.columns

ridge = Ridge(alpha=10)
ridge.fit(X,y)

d = {'Feature': ridge_feats, 'Coef': ridge.coef_}
ridge_df = pd.DataFrame(d)
print(ridge_df)
print()
print(f'Training Score: {ridge.score(X, y)}')
print(f'Test Score: {ridge.score(X_reg_test, y_reg_test)}')
# Out:
#    Feature       Coef
# 0     eigb  -5.028160
# 1     cdmq  -0.038167
# 2     uzqa  -2.767551
# 3     wmej   1.399662
# 4     ilat  68.370714
# 5     azdo  39.773747
# 6     kafk  -7.420202
# 7     icwb  77.961790
# 8     bhux   0.363174
# 9     qpnw  81.240970
# 10    kxtp  -0.430598
# 11    rugc  50.152211
# 12    mfiv   4.555465
# 13    pixm  -9.310180
# 14    zsvm  -2.103611
# 15    inxi  73.857575
# 16    lgsv   1.625805
# 17    rirh   1.142022
# 18    cgfh   0.728932
# 19    rhud  35.266249
# 20    jrjm   2.759696
# 21    ozye  26.766414
#
# Training Score: 0.8630280475926932
# Test Score: 0.8465595164015038

# %%
# compare the coefficients from the linear regression, lasso, and ridge models
d = {'Original': X_reg.columns, 'Original Coeffs': lr_model.coef_.tolist(), 'Lasso': lasso_feats, 'Lasso Coeffs': lasso.coef_, 'Ridge': ridge_feats, 'Ridge Coeffs': ridge.coef_}
reg_df = pd.DataFrame(d)
print(reg_df[1:])
# Out:
#    Original  Original Coeffs Lasso  Lasso Coeffs Ridge  Ridge Coeffs
# 1      cdmq         0.076619  cdmq     -0.000000  cdmq     -0.038167
# 2      uzqa        -2.765886  uzqa     -0.000000  uzqa     -2.767551
# 3      wmej         1.294516  wmej      0.000000  wmej      1.399662
# 4      ilat        70.980843  ilat     64.922674  ilat     68.370714
# 5      azdo        42.506779  azdo     35.979376  azdo     39.773747
# 6      kafk        -7.255580  kafk     -2.763783  kafk     -7.420202
# 7      icwb        82.854626  icwb     75.003580  icwb     77.961790
# 8      bhux         0.635165  bhux     -0.000000  bhux      0.363174
# 9      qpnw        81.288660  qpnw     77.770297  qpnw     81.240970
# 10     kxtp        -0.103660  kxtp     -0.000000  kxtp     -0.430598
# 11     rugc        51.351805  rugc     46.933818  rugc     50.152211
# 12     mfiv         4.665903  mfiv      0.000000  mfiv      4.555465
# 13     pixm       -16.158217  pixm     -4.416576  pixm     -9.310180
# 14     zsvm        -1.939995  zsvm     -0.000000  zsvm     -2.103611
# 15     inxi        83.310797  inxi     71.669928  inxi     73.857575
# 16     lgsv         1.295766  lgsv      0.000000  lgsv      1.625805
# 17     rirh         0.861688  rirh      0.000000  rirh      1.142022
# 18     cgfh         0.858174  cgfh     -0.000000  cgfh      0.728932
# 19     rhud       214.060280  rhud     31.773544  rhud     35.266249
# 20     jrjm         4.724680  jrjm      0.000000  jrjm      2.759696
# 21     ozye        27.674017  ozye     21.928699  ozye     26.766414

# %%
# X_reg correlation with target
X_reg.corrwith(y_train).plot.bar(
    title='Correlation with Dependent Variable', rot=90,grid=True
);

# %%
# https://stackoverflow.com/questions/17778394/list-highest-correlation-pairs-from-a-large-correlation-matrix-in-pandas
corr_matrix = X_reg.corr().abs()
print(corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
                  .stack()
                  .sort_values(ascending=False))
# Out:
# qpnw  ozye    0.146219
# kafk  zsvm    0.142522
# eigb  inxi    0.134909
# wmej  inxi    0.129613
# pixm  lgsv    0.120676
#                 ...
#       inxi    0.000852
# cdmq  cgfh    0.000653
# lgsv  jrjm    0.000649
# eigb  jrjm    0.000346
# cdmq  mfiv    0.000031
# Length: 231, dtype: float64

# %%
# show correlation heat map for features, check for multicollinearity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# correlation matrix
sns.set(style="white")

# compute the correlation matrix
corr = X_reg.corr()

# generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# set up the matplotlib figure
# f, ax = plt.subplots()
f = plt.figure(figsize=(10, 10))

# generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True);

plt.tight_layout()

# %%
# ols summary recall
print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     101.3
# Date:                Thu, 19 Oct 2023   Prob (F-statistic):          1.25e-137
# Time:                        04:31:59   Log-Likelihood:                -2121.0
# No. Observations:                 375   AIC:                             4288.
# Df Residuals:                     352   BIC:                             4378.
# Df Model:                          22
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -107.3842     15.044     -7.138      0.000    -136.972     -77.797
# eigb          -8.9609      6.820     -1.314      0.190     -22.373       4.452
# cdmq           0.0766      3.575      0.021      0.983      -6.954       7.107
# uzqa          -2.7659      3.883     -0.712      0.477     -10.403       4.871
# wmej           1.2945      3.794      0.341      0.733      -6.168       8.757
# ilat          70.9808      3.823     18.567      0.000      63.462      78.499
# azdo          42.5068      3.973     10.698      0.000      34.692      50.321
# kafk          -7.2556      3.601     -2.015      0.045     -14.337      -0.174
# icwb          82.8546      4.001     20.707      0.000      74.985      90.724
# bhux           0.6352      3.706      0.171      0.864      -6.654       7.924
# qpnw          81.2887      3.715     21.882      0.000      73.983      88.595
# kxtp          -0.1037      3.694     -0.028      0.978      -7.369       7.162
# rugc          51.3518      3.795     13.533      0.000      43.889      58.815
# mfiv           4.6659      3.736      1.249      0.213      -2.682      12.013
# pixm         -16.1582      6.390     -2.529      0.012     -28.726      -3.590
# zsvm          -1.9400      3.807     -0.510      0.611      -9.427       5.548
# inxi          83.3108      4.197     19.849      0.000      75.056      91.565
# lgsv           1.2958      3.939      0.329      0.742      -6.451       9.042
# rirh           0.8617      4.162      0.207      0.836      -7.324       9.048
# cgfh           0.8582      3.883      0.221      0.825      -6.779       8.495
# rhud         214.0603     22.412      9.551      0.000     169.981     258.139
# jrjm           4.7247      6.315      0.748      0.455      -7.696      17.145
# ozye          27.6740      3.779      7.324      0.000      20.243      35.105
# ==============================================================================
# Omnibus:                       12.971   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               19.484
# Skew:                           0.255   Prob(JB):                     5.88e-05
# Kurtosis:                       3.993   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# create a statsmodel ols model using the relevant features found in the Lasso model, print the summary

# statsmodel ols feature selection per l1 regularization

import statsmodels.api as sm

X_sel_feats=X_reg.drop(['pixm','kafk'],axis=1)
X_sel_feats.insert(0,'constant',1)
sel_feats_model=sm.OLS(y_train,X_sel_feats).fit()
print(sel_feats_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                     108.4
# Date:                Thu, 19 Oct 2023   Prob (F-statistic):          1.71e-137
# Time:                        04:34:52   Log-Likelihood:                -2126.4
# No. Observations:                 375   AIC:                             4295.
# Df Residuals:                     354   BIC:                             4377.
# Df Model:                          20
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# constant    -123.0928     14.138     -8.706      0.000    -150.898     -95.287
# eigb          -9.6679      6.892     -1.403      0.162     -23.223       3.887
# cdmq          -0.5479      3.606     -0.152      0.879      -7.640       6.544
# uzqa          -2.5011      3.923     -0.638      0.524     -10.217       5.215
# wmej           2.1105      3.826      0.552      0.582      -5.413       9.634
# ilat          70.6388      3.866     18.274      0.000      63.037      78.241
# azdo          42.6286      4.019     10.608      0.000      34.725      50.532
# icwb          81.5620      4.020     20.291      0.000      73.656      89.467
# bhux           0.7495      3.746      0.200      0.842      -6.618       8.117
# qpnw          82.2463      3.744     21.969      0.000      74.883      89.609
# kxtp           0.4285      3.728      0.115      0.909      -6.903       7.761
# rugc          52.2018      3.822     13.658      0.000      44.685      59.718
# mfiv           4.1956      3.775      1.111      0.267      -3.229      11.620
# zsvm          -2.9998      3.820     -0.785      0.433     -10.512       4.512
# inxi          83.2581      4.246     19.610      0.000      74.908      91.608
# lgsv           0.2264      3.953      0.057      0.954      -7.547       8.000
# rirh           0.3014      4.200      0.072      0.943      -7.958       8.561
# cgfh           0.1778      3.921      0.045      0.964      -7.533       7.889
# rhud         217.6141     22.638      9.613      0.000     173.092     262.136
# jrjm           5.2487      6.384      0.822      0.412      -7.306      17.804
# ozye          27.0240      3.816      7.082      0.000      19.520      34.528
# ==============================================================================
# Omnibus:                        9.016   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               14.327
# Skew:                          -0.120   Prob(JB):                     0.000774
# Kurtosis:                       3.927   Cond. No.                         11.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Model Comparison
#
# Provide a comparison between the original OLS model and the reduced features OLS model created with the help of l1 regularization. Make mention of the following:
#
# * R-squared
# * Adj R-squared
# * F-statistic
# * AIC and BIC
# * The coefficients that are common in both models
# * The standard error for each coefficient
# * The t-statistic
# * The critical value
# * The p-value
# * The 95% confidence interval

# %%
# create, train, and test a model using a pipeline that includes a StandardScaler and a Lasso Regression model, output the training and testing scores

from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

pipe = [
    ('scalar', StandardScaler()),
    ('model', Lasso(alpha=5, fit_intercept=True))
]

pipe_model = Pipeline(pipe)
pipe_model.fit(X_reg.values, y_train.values)

d = {'Feature': X_reg.columns, 'Coef': pipe_model['model'].coef_}
pipe_df = pd.DataFrame(d)
print(pipe_df)
print()
print(f'Training Score: {pipe_model.score(X_reg.values, y_train.values)}')
print(f'Test Score: {pipe_model.score(X_reg_test, y_reg_test)}')
print()
print(f'Training Score: {lasso.score(X, y)}')
print(f'Test Score: {lasso.score(X_reg_test, y_reg_test)}')
# Out:
#    Feature       Coef
# 0     eigb  -0.000000
# 1     cdmq  -0.000000
# 2     uzqa  -0.000000
# 3     wmej   0.000000
# 4     ilat  64.922674
# 5     azdo  35.979376
# 6     kafk  -2.763783
# 7     icwb  75.003580
# 8     bhux  -0.000000
# 9     qpnw  77.770297
# 10    kxtp  -0.000000
# 11    rugc  46.933818
# 12    mfiv   0.000000
# 13    pixm  -4.416576
# 14    zsvm  -0.000000
# 15    inxi  71.669928
# 16    lgsv   0.000000
# 17    rirh   0.000000
# 18    cgfh  -0.000000
# 19    rhud  31.773544
# 20    jrjm   0.000000
# 21    ozye  21.928699
#
# Training Score: 0.85442719608065
# Test Score: 0.10810284651637547
#
# Training Score: 0.85442719608065
# Test Score: 0.847653115520031

# %%
# compare
d = {'Original': X_reg.columns, 'Original Coef': lr_model.coef_.tolist(),
     'Lasso': lasso_feats, 'Lasso Coef': lasso.coef_,
     'Ridge': ridge_feats, 'Ridge Coef': ridge.coef_,
     'Pipe': X_reg.columns, 'Pipe Coef': pipe_model['model'].coef_}
reg_df = pd.DataFrame(d)
print(reg_df[1:])
# Out:
#    Original  Original Coef Lasso  Lasso Coef Ridge  Ridge Coef  Pipe  \
# 1      cdmq       0.076619  cdmq   -0.000000  cdmq   -0.038167  cdmq
# 2      uzqa      -2.765886  uzqa   -0.000000  uzqa   -2.767551  uzqa
# 3      wmej       1.294516  wmej    0.000000  wmej    1.399662  wmej
# 4      ilat      70.980843  ilat   64.922674  ilat   68.370714  ilat
# 5      azdo      42.506779  azdo   35.979376  azdo   39.773747  azdo
# 6      kafk      -7.255580  kafk   -2.763783  kafk   -7.420202  kafk
# 7      icwb      82.854626  icwb   75.003580  icwb   77.961790  icwb
# 8      bhux       0.635165  bhux   -0.000000  bhux    0.363174  bhux
# 9      qpnw      81.288660  qpnw   77.770297  qpnw   81.240970  qpnw
# 10     kxtp      -0.103660  kxtp   -0.000000  kxtp   -0.430598  kxtp
# 11     rugc      51.351805  rugc   46.933818  rugc   50.152211  rugc
# 12     mfiv       4.665903  mfiv    0.000000  mfiv    4.555465  mfiv
# 13     pixm     -16.158217  pixm   -4.416576  pixm   -9.310180  pixm
# 14     zsvm      -1.939995  zsvm   -0.000000  zsvm   -2.103611  zsvm
# 15     inxi      83.310797  inxi   71.669928  inxi   73.857575  inxi
# 16     lgsv       1.295766  lgsv    0.000000  lgsv    1.625805  lgsv
# 17     rirh       0.861688  rirh    0.000000  rirh    1.142022  rirh
# 18     cgfh       0.858174  cgfh   -0.000000  cgfh    0.728932  cgfh
# 19     rhud     214.060280  rhud   31.773544  rhud   35.266249  rhud
# 20     jrjm       4.724680  jrjm    0.000000  jrjm    2.759696  jrjm
# 21     ozye      27.674017  ozye   21.928699  ozye   26.766414  ozye
#
#     Pipe Coef
# 1   -0.000000
# 2   -0.000000
# 3    0.000000
# 4   64.922674
# 5   35.979376
# 6   -2.763783
# 7   75.003580
# 8   -0.000000
# 9   77.770297
# 10  -0.000000
# 11  46.933818
# 12   0.000000
# 13  -4.416576
# 14  -0.000000
# 15  71.669928
# 16   0.000000
# 17   0.000000
# 18  -0.000000
# 19  31.773544
# 20   0.000000
# 21  21.928699

# %% [markdown]
# ## Assignment Summary
#
# On an overall, have analyzed the dataset, cleaned and explored this dataset containing variables which are unknown to knowledge of as the variables have been anonymized. while cleaning the dataset there were few more null values, reviewed the dataset manually and then moved on to find the collinearity and multicollinearity, where specific characteristics exhibited robust correlations. To tackle this issue, we eliminated two sets of highly correlated features, which enabled us to conduct our analysis successfully by using the meansquare equation and r square equation. Finally, we identified the four features with the most statistically significant p-values in the results obtained from the Ordinary Least Squares (OLS) regression.
#
# Histograms show that X_train comprises both skewed and normal data. We used median interpolation for the skewed data and the regular technique for the normal data. We removed one of the columns after determining the VIF for each variable to eliminate multicollinearity.Multicollinearity was removed from the correlation heat map.The X_train to Target Y_train correlation is then computed, revealing that the mean and the target are closely related.
#
# We built a linear regression model and then calculated the mean squared error and r-squared error parameters, as well as intercepts and coefficients. The squared values are used to reduce errors, and we then created a summary of our model, which has the same coefficients and r-squared values as our original model.
#
# Histograms show that X_train comprises both skewed and normal data. We used median interpolation for the skewed data and the regular technique for the normal data. We removed one of the columns after determining the VIF for each variable to eliminate multicollinearity.Multicollinearity was removed from the correlation heat map.The X_train to Target Y_train correlation is then computed, revealing that the mean and the target are closely related.
#
# We built a linear regression model and then calculated the mean squared error and r-squared error parameters, as well as intercepts and coefficients. The squared values are used to reduce errors, and we then created a summary of our model, which has the same coefficients and r-squared values as our original model.
